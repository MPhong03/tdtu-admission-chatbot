# %% [markdown]
# # Huấn luyện mô hình NER với spaCy 3.x

# %% [markdown]
# ## I. Import

# %%
import spacy
from spacy.tokens import DocBin
from spacy.training.example import Example
from spacy.training.iob_utils import offsets_to_biluo_tags
import random
import json

# %% [markdown]
# ## II. Load Data

# %%
# Load dữ liệu
with open("./data/ner_data.json", "r", encoding="utf-8") as f:
    raw = json.load(f)["dataset"]

# %%
# Tạo mô hình trắng
nlp = spacy.blank("vi")
ner = nlp.add_pipe("ner")

# %%
# Bổ sung nhãn từ dữ liệu
for item in raw:
    for _, _, label in item["entities"]:
        ner.add_label(label)

# %%
# Chuẩn bị dữ liệu huấn luyện, loại bỏ entity sai alignment
TRAIN_DATA_CLEAN = []

for item in raw:
    text = item["text"]
    entities = item["entities"]
    doc = nlp.make_doc(text)
    try:
        tags = offsets_to_biluo_tags(doc, entities)
        if "-" not in tags:  # hợp lệ
            example = Example.from_dict(doc, {"entities": entities})
            TRAIN_DATA_CLEAN.append(example)
    except:
        continue  # bỏ qua nếu sai lớn hơn

print(f"Số mẫu hợp lệ: {len(TRAIN_DATA_CLEAN)}")
# Out:
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế-K7340201X của ngành Khoa học m..." with entities "[[3, 29, 'Programme'], [40, 59, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 74, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ngành Kỹ thuật điện tử - viễn thông thuộc nhóm ngà..." with entities "[[6, 35, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 146, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ngành Kỹ thuật xây dựng công trình giao thông thuộ..." with entities "[[6, 45, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Ngôn ngữ Anh ở Đại học Kinh tế TP.HCM..." with entities "[[13, 25, 'Major'], [28, 50, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 101, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 135, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 122, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế - K7340120L của ngành Bảo hộ l..." with entities "[[3, 31, 'Programme'], [42, 57, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Kỹ thuật điện tử - viễn thông ở Đại h..." with entities "[[13, 42, 'Major'], [45, 67, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Quản lý xây dựng ở Đại học Kinh tế TP..." with entities "[[13, 29, 'Major'], [32, 54, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Kiểm toán (Chuyên ngành Kiể..." with entities "[[3, 12, 'Programme'], [23, 78, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 112, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Kỹ thuật phần mềm học trong..." with entities "[[3, 12, 'Programme'], [23, 40, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Học Thiết kế nội thất cần điều kiện gì?" with entities "[[4, 21, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 77, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Du lịch (Chuyên ngành Hướng dẫn du lị..." with entities "[[13, 53, 'Major'], [56, 78, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Kế toán ở Đại học Kinh tế TP.HCM." with entities "[[13, 20, 'Major'], [23, 45, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Mạng máy tính và Truyền thông dữ liệu..." with entities "[[13, 50, 'Major'], [53, 75, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Quản trị kinh doanh (Chuyên..." with entities "[[3, 12, 'Programme'], [23, 81, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Kỹ thuật xây dựng ở Đại học Kinh tế T..." with entities "[[13, 30, 'Major'], [33, 55, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Kiểm toán (Chuyên ngành Kiểm toán và ..." with entities "[[13, 68, 'Major'], [71, 93, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 73, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Quản lý thể dục thể thao (C..." with entities "[[3, 12, 'Programme'], [23, 67, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Luật ở Đại học Kinh tế TP.HCM." with entities "[[13, 17, 'Major'], [20, 42, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiêu chuẩn của ngành Thống kê học trong mấy năm..." with entities "[[3, 13, 'Programme'], [24, 32, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế - K7480101T của ngành Dược học..." with entities "[[3, 31, 'Programme'], [42, 46, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Thiết kế thời trang ở Đại học Kinh tế..." with entities "[[13, 32, 'Major'], [35, 57, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Kỹ thuật điện ở Đại học Kinh tế TP.HC..." with entities "[[13, 26, 'Major'], [29, 51, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Đại học bằng tiếng Anh của ngành Kỹ thuật cơ đi..." with entities "[[3, 25, 'Programme'], [36, 55, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Quy hoạch vùng và đô thị ở Đại học Ki..." with entities "[[13, 37, 'Major'], [40, 62, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 123, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 81, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Học Thiết kế đồ họa cần điều kiện gì?" with entities "[[4, 19, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Quản trị kinh doanh (Chuyên ngành Quả..." with entities "[[13, 71, 'Major'], [74, 96, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 119, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Kiến trúc ở Đại học Kinh tế TP.HCM." with entities "[[13, 22, 'Major'], [25, 47, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Học Ngôn ngữ Trung Quốc cần điều kiện gì?" with entities "[[4, 23, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế - K7340120L của ngành Khoa học..." with entities "[[3, 31, 'Programme'], [42, 61, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Học Thiết kế thời trang cần điều kiện gì?" with entities "[[4, 23, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế của ngành Luật học trong mấy n..." with entities "[[3, 19, 'Programme'], [30, 34, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 70, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Khoa học máy tính ở Đại học Kinh tế T..." with entities "[[13, 30, 'Major'], [33, 55, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 72, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Du lịch (Chuyên ngành Quản lý du lịch..." with entities "[[13, 51, 'Major'], [54, 76, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Ngôn ngữ Anh học trong mấy ..." with entities "[[3, 12, 'Programme'], [23, 35, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế - K7480101L của ngành Kỹ thuật..." with entities "[[3, 31, 'Programme'], [42, 61, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Kỹ thuật điện tử - viễn thô..." with entities "[[3, 12, 'Programme'], [23, 101, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Quản trị kinh doanh (Chuyên..." with entities "[[3, 12, 'Programme'], [23, 85, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Bảo hộ lao động ở Đại học Kinh tế TP...." with entities "[[13, 28, 'Major'], [31, 53, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 83, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiêu chuẩn của ngành Dược học trong mấy năm?" with entities "[[3, 13, 'Programme'], [24, 28, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Tài chính - Ngân hàng ở Đại học Kinh ..." with entities "[[13, 34, 'Major'], [37, 59, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Ngôn ngữ Trung Quốc ở Đại học Kinh tế..." with entities "[[13, 32, 'Major'], [35, 57, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Marketing học trong mấy năm..." with entities "[[3, 12, 'Programme'], [23, 32, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế - K7480101L của ngành Thống kê..." with entities "[[3, 31, 'Programme'], [42, 50, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 112, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 61, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 75, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Kỹ thuật điều khiển và tự đ..." with entities "[[3, 12, 'Programme'], [23, 57, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế của ngành Khoa học môi trường ..." with entities "[[3, 19, 'Programme'], [30, 49, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Toán ứng dụng ở Đại học Kinh tế TP.HC..." with entities "[[13, 26, 'Major'], [29, 51, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Đại học bằng tiếng Anh của ngành Thiết kế nội t..." with entities "[[3, 25, 'Programme'], [36, 53, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế-K7340201X của ngành Kỹ thuật c..." with entities "[[3, 29, 'Programme'], [40, 59, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Tài chính - Ngân hàng (Chuy..." with entities "[[3, 12, 'Programme'], [23, 77, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Marketing ở Đại học Kinh tế TP.HCM." with entities "[[13, 22, 'Major'], [25, 47, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Kỹ thuật điện tử - viễn thô..." with entities "[[3, 12, 'Programme'], [23, 52, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 84, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Công nghệ kỹ thuật môi trường (Chuyên..." with entities "[[13, 91, 'Major'], [94, 116, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Kỹ thuật phần mềm ở Đại học Kinh tế T..." with entities "[[13, 30, 'Major'], [33, 55, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 95, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Học du-lich cần điều kiện gì?" with entities "[[4, 11, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế-K7340201M của ngành Công tác x..." with entities "[[3, 29, 'Programme'], [40, 55, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Luật học trong mấy năm?" with entities "[[3, 12, 'Programme'], [23, 27, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 92, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 85, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Tài chính - Ngân hàng (Chuyên ngành T..." with entities "[[13, 67, 'Major'], [70, 92, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Công tác xã hội ở Đại học Kinh tế TP...." with entities "[[13, 28, 'Major'], [31, 53, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Công nghệ sinh học ở Đại học Kinh tế ..." with entities "[[13, 31, 'Major'], [34, 56, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế-K7340201M của ngành Thiết kế n..." with entities "[[3, 29, 'Programme'], [40, 57, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Quản lý thể dục thể thao (Chuyên ngàn..." with entities "[[13, 57, 'Major'], [60, 82, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Kỹ thuật điều khiển và tự động hóa ở ..." with entities "[[13, 47, 'Major'], [50, 72, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Quản lý thể dục thể thao (Chuyên ngàn..." with entities "[[13, 91, 'Major'], [94, 116, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế - K7340120L của ngành Công tác..." with entities "[[3, 31, 'Programme'], [42, 57, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Đại học bằng tiếng Anh của ngành Dược học trong..." with entities "[[3, 25, 'Programme'], [36, 40, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế-K7340201X của ngành Thống kê h..." with entities "[[3, 29, 'Programme'], [40, 48, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Đại học bằng tiếng Anh của ngành Luật học trong..." with entities "[[3, 25, 'Programme'], [36, 40, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Thống kê ở Đại học Kinh tế TP.HCM." with entities "[[13, 21, 'Major'], [24, 46, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 115, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 87, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Kỹ thuật cơ điện tử học tro..." with entities "[[3, 12, 'Programme'], [23, 42, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 91, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế của ngành Bảo hộ lao động học ..." with entities "[[3, 19, 'Programme'], [30, 45, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiêu chuẩn của ngành Kế toán học trong mấy năm?" with entities "[[3, 13, 'Programme'], [24, 31, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế - K7340120L của ngành Kế toán ..." with entities "[[3, 31, 'Programme'], [42, 49, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế - K7480101T của ngành Bảo hộ l..." with entities "[[3, 31, 'Programme'], [42, 57, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 81, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Quan hệ lao động (Chuyên ngành Quản l..." with entities "[[13, 99, 'Major'], [102, 124, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Khoa học máy tính học trong..." with entities "[[3, 12, 'Programme'], [23, 40, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Kiến trúc học trong mấy năm..." with entities "[[3, 12, 'Programme'], [23, 32, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Thiết kế nội thất ở Đại học Kinh tế T..." with entities "[[13, 30, 'Major'], [33, 55, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Đại học bằng tiếng Anh của ngành Bảo hộ lao độn..." with entities "[[3, 25, 'Programme'], [36, 51, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế - K7480101T của ngành Công tác..." with entities "[[3, 31, 'Programme'], [42, 57, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiêu chuẩn của ngành Luật học trong mấy năm?" with entities "[[3, 13, 'Programme'], [24, 28, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 86, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 96, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Kỹ thuật điện tử - viễn thông (Chuyên..." with entities "[[13, 91, 'Major'], [94, 116, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế-K7340201M của ngành Kỹ thuật c..." with entities "[[3, 29, 'Programme'], [40, 59, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế của ngành Dược học trong mấy n..." with entities "[[3, 19, 'Programme'], [30, 34, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ...
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 154, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Xã hội học ở Đại học Kinh tế TP.HCM." with entities "[[13, 23, 'Major'], [26, 48, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Quản lý xây dựng học trong ..." with entities "[[3, 12, 'Programme'], [23, 39, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Công nghệ kỹ thuật môi trườ..." with entities "[[3, 12, 'Programme'], [23, 101, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiêu chuẩn của ngành Công tác xã hội học trong ..." with entities "[[3, 13, 'Programme'], [24, 39, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế-K7340201X của ngành Thiết kế n..." with entities "[[3, 29, 'Programme'], [40, 57, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Đại học bằng tiếng Anh của ngành Công tác xã hộ..." with entities "[[3, 25, 'Programme'], [36, 51, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 97, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 64, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 72, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế-K7340201X của ngành Công tác x..." with entities "[[3, 29, 'Programme'], [40, 55, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 67, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 76, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Quản trị kinh doanh (Chuyên ngành Quả..." with entities "[[13, 75, 'Major'], [78, 100, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Kỹ thuật cơ điện tử ở Đại học Kinh tế..." with entities "[[13, 32, 'Major'], [35, 57, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Dược học trong mấy năm?" with entities "[[3, 12, 'Programme'], [23, 27, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Kỹ thuật xây dựng công trình giao thô..." with entities "[[13, 52, 'Major'], [55, 77, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế - K7340120L của ngành Kỹ thuật..." with entities "[[3, 31, 'Programme'], [42, 61, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế - K7480101L của ngành Bảo hộ l..." with entities "[[3, 31, 'Programme'], [42, 57, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 86, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 75, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 108, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật kinh tế) của..." with entities "[[3, 46, 'Programme'], [57, 66, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Đại học bằng tiếng Anh của ngành Thống kê học t..." with entities "[[3, 25, 'Programme'], [36, 44, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế - K7340120L của ngành Thiết kế..." with entities "[[3, 31, 'Programme'], [42, 59, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Quản lý thể dục thể thao (C..." with entities "[[3, 12, 'Programme'], [23, 101, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Kinh doanh quốc tế ở Đại học Kinh tế ..." with entities "[[13, 31, 'Major'], [34, 56, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế của ngành Công tác xã hội học ..." with entities "[[3, 19, 'Programme'], [30, 45, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học Khoa học môi trường ở Đại học Kinh tế..." with entities "[[13, 32, 'Major'], [35, 57, 'University']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 130, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế - K7480101T của ngành Luật học..." with entities "[[3, 31, 'Programme'], [42, 46, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Kỹ thuật xây dựng công trìn..." with entities "[[3, 12, 'Programme'], [23, 62, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Liên kết quốc tế - K7480101T của ngành Thống kê..." with entities "[[3, 31, 'Programme'], [42, 50, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Thống kê học trong mấy năm?" with entities "[[3, 12, 'Programme'], [23, 31, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến của ngành Kế toán học trong mấy năm?" with entities "[[3, 12, 'Programme'], [23, 30, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Số mẫu hợp lệ: 9423
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Tiên tiến: Luật (Chuyên ngành Luật thương mại q..." with entities "[[3, 57, 'Programme'], [68, 89, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(

# %% [markdown]
# ## III. Training

# %%
# Huấn luyện mô hình
optimizer = nlp.begin_training()
for i in range(10):
    random.shuffle(TRAIN_DATA_CLEAN)
    losses = {}
    for example in TRAIN_DATA_CLEAN:
        nlp.update([example], drop=0.3, sgd=optimizer, losses=losses)
    print(f"Epoch {i+1} - Loss: {losses}")
# Out:
# Epoch 1 - Loss: {'ner': np.float32(1639.6969)}
# Epoch 2 - Loss: {'ner': np.float32(300.68536)}
# Epoch 3 - Loss: {'ner': np.float32(299.97)}
# Epoch 4 - Loss: {'ner': np.float32(184.85022)}
# Epoch 5 - Loss: {'ner': np.float32(135.07251)}
# Epoch 6 - Loss: {'ner': np.float32(85.19305)}
# Epoch 7 - Loss: {'ner': np.float32(135.1073)}
# Epoch 8 - Loss: {'ner': np.float32(72.80031)}
# Epoch 9 - Loss: {'ner': np.float32(148.09901)}
# Epoch 10 - Loss: {'ner': np.float32(92.86531)}

# %% [markdown]
# ## IV. Save model

# %%
# nlp.to_disk("../ner_model")
# print("Mô hình đã lưu vào thư mục ner_model")

# Lưu mô hình
nlp.to_disk("../ner_model_cleaned")
print("Đã lưu mô hình vào thư mục ner_model_cleaned")
# Out:
# Đã lưu mô hình vào thư mục ner_model_cleaned

# %% [markdown]
# ## V. Save invalid NER data

# %%
# with open("data/invalid_ner_data.json", "w", encoding="utf-8") as f:
#     json.dump(invalid_data, f, ensure_ascii=False, indent=2)
# print(f"Đã lưu {len(invalid_data)} câu lỗi vào file: data/invalid_ner_data.json")
# Out:
# Đã lưu 1120 câu lỗi vào file: data/invalid_ner_data.json

# %% [markdown]
# ## VI. Test

# %%
ner_nlp = spacy.load("../ner_model_cleaned")

# %%
# ======== METHODS =========
def extract_entities(text: str):
    doc = ner_nlp(text)
    return [
        {
            "text": ent.text,
            "start": ent.start_char,
            "end": ent.end_char,
            "label": ent.label_
        }
        for ent in doc.ents
    ]

# %%
text = "Ngành quản trị du lịch có học phí bao nhiêu"
entities = extract_entities(text)

print(entities)
# Out:
# [{'text': 'quản trị du lịch', 'start': 6, 'end': 22, 'label': 'Major'}]
