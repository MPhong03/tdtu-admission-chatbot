# %% [markdown]
# # Huấn luyện mô hình NER với spaCy 3.x

# %% [markdown]
# ## I. Import

# %%
import spacy
from spacy.tokens import DocBin
from spacy.training.example import Example
from spacy.training.iob_utils import offsets_to_biluo_tags
import random
import json
from tqdm import tqdm
from spacy.util import minibatch

# %%
# Chuyển sang GPU nếu có
spacy.require_gpu()

if spacy.prefer_gpu():
    print("Using GPU")
else:
    print("Not using GPU, falling back to CPU")

from thinc.api import get_current_ops
print("Current device:", get_current_ops().__class__.__name__)
# Out:
# Using GPU
# Current device: CupyOps

# %% [markdown]
# ## II. Load Data

# %%
# Load dữ liệu
with open("./data/ner_data.json", "r", encoding="utf-8") as f:
    raw = json.load(f)["dataset"]

# %%
# Tạo mô hình trắng
nlp = spacy.blank("vi")
ner = nlp.add_pipe("ner")

# %%
# Bổ sung nhãn từ dữ liệu
for item in raw:
    for _, _, label in item["entities"]:
        ner.add_label(label)

# %%
# Chuẩn bị dữ liệu huấn luyện, loại bỏ entity sai alignment
TRAIN_DATA_CLEAN = []

for item in raw:
    text = item["text"]
    entities = item["entities"]
    doc = nlp.make_doc(text)
    try:
        tags = offsets_to_biluo_tags(doc, entities)
        if "-" not in tags:  # hợp lệ
            example = Example.from_dict(doc, {"entities": entities})
            TRAIN_DATA_CLEAN.append(example)
    except:
        continue  # bỏ qua nếu sai lớn hơn

print(f"Số mẫu hợp lệ: {len(TRAIN_DATA_CLEAN)}")
# Out:
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Du lịch (Chuyên ngành Hướng dẫn du lịch) đào tạ..." with entities "[[3, 43, 'Major'], [58, 86, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Dược đào tạo ngành Tiên tiến: Luật (Chuyên ngàn..." with entities "[[3, 7, 'Major'], [22, 65, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Toán ứng dụng đào tạo ngành Tiên tiến có yêu cầ..." with entities "[[3, 16, 'Major'], [31, 40, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Marketing đào tạo ngành Liên kết quốc tế - K734..." with entities "[[3, 12, 'Major'], [27, 55, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kiến trúc đào tạo ngành Đại học bằng tiếng Anh ..." with entities "[[3, 12, 'Major'], [27, 49, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Dược đào tạo ngành Tiên tiến: Luật (Chuyên ngàn..." with entities "[[3, 7, 'Major'], [22, 76, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thiết kế nội thất đào tạo ngành Liên kết quốc t..." with entities "[[3, 20, 'Major'], [35, 63, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điện đào tạo ngành Đại học bằng tiếng ..." with entities "[[3, 16, 'Major'], [31, 53, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật hóa học đào tạo ngành Liên kết quốc tế..." with entities "[[3, 19, 'Major'], [34, 62, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điều khiển và tự động hóa đào tạo ngàn..." with entities "[[3, 37, 'Major'], [52, 106, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điện tử - viễn thông đào tạo ngành Tiê..." with entities "[[3, 32, 'Major'], [47, 101, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Du lịch (Chuyên ngành Hướng dẫn du lịch) đào tạ..." with entities "[[3, 43, 'Major'], [58, 84, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kiểm toán (Chuyên ngành Kiểm toán và Phân tích ..." with entities "[[3, 58, 'Major'], [73, 83, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Du lịch (Chuyên ngành Quản lý du lịch) đào tạo ..." with entities "[[3, 41, 'Major'], [56, 66, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thiết kế thời trang đào tạo ngành Liên kết quốc..." with entities "[[3, 22, 'Major'], [37, 65, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Khoa học môi trường đào tạo ngành Liên kết quốc..." with entities "[[3, 22, 'Major'], [37, 65, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điện tử - viễn thông (Chuyên ngành Kỹ ..." with entities "[[3, 81, 'Major'], [96, 139, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điều khiển và tự động hóa đào tạo ngàn..." with entities "[[3, 37, 'Major'], [52, 61, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điện đào tạo ngành Tiêu chuẩn có yêu c..." with entities "[[3, 16, 'Major'], [31, 41, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Du lịch (Chuyên ngành Hướng dẫn du lịch) đào tạ..." with entities "[[3, 43, 'Major'], [58, 74, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Du lịch (Chuyên ngành Quản lý du lịch) đào tạo ..." with entities "[[3, 41, 'Major'], [56, 84, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Luật đào tạo ngành Liên kết quốc tế - K7480101L..." with entities "[[3, 7, 'Major'], [22, 50, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Khoa học môi trường đào tạo ngành Tiêu chuẩn có..." with entities "[[3, 22, 'Major'], [37, 47, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Mạng máy tính và Truyền thông dữ liệu đào tạo n..." with entities "[[3, 40, 'Major'], [55, 81, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điện tử - viễn thông (Chuyên ngành Kỹ ..." with entities "[[3, 81, 'Major'], [96, 106, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Mạng máy tính và Truyền thông dữ liệu đào tạo n..." with entities "[[3, 40, 'Major'], [55, 83, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Marketing đào tạo ngành Liên kết quốc tế-K73402..." with entities "[[3, 12, 'Major'], [27, 53, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điện tử - viễn thông đào tạo ngành Tiê..." with entities "[[3, 32, 'Major'], [47, 56, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật cơ điện tử đào tạo ngành Đại học bằng ..." with entities "[[3, 22, 'Major'], [37, 59, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điện tử - viễn thông (Chuyên ngành Kỹ ..." with entities "[[3, 81, 'Major'], [96, 122, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thiết kế thời trang đào tạo ngành Đại học bằng ..." with entities "[[3, 22, 'Major'], [37, 59, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thiết kế thời trang đào tạo ngành Tiên tiến: Lu..." with entities "[[3, 22, 'Major'], [37, 80, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Khoa học máy tính đào tạo ngành Liên kết quốc t..." with entities "[[3, 20, 'Major'], [35, 63, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Toán ứng dụng đào tạo ngành Liên kết quốc tế - ..." with entities "[[3, 16, 'Major'], [31, 59, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ngành Kỹ thuật điện tử - viễn thông thuộc nhóm ngà..." with entities "[[6, 35, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật cơ điện tử đào tạo ngành Liên kết quốc..." with entities "[[3, 22, 'Major'], [37, 53, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật cơ điện tử đào tạo ngành Liên kết quốc..." with entities "[[3, 22, 'Major'], [37, 63, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Khoa học máy tính đào tạo ngành Tiêu chuẩn có y..." with entities "[[3, 20, 'Major'], [35, 45, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật phần mềm đào tạo ngành Liên kết quốc t..." with entities "[[3, 20, 'Major'], [35, 63, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật xây dựng đào tạo ngành Liên kết quốc t..." with entities "[[3, 20, 'Major'], [35, 61, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Ngôn ngữ Anh đào tạo ngành Liên kết quốc tế-K73..." with entities "[[3, 15, 'Major'], [30, 56, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Du lịch (Chuyên ngành Hướng dẫn du lịch) đào tạ..." with entities "[[3, 43, 'Major'], [58, 68, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Toán ứng dụng đào tạo ngành Liên kết quốc tế có..." with entities "[[3, 16, 'Major'], [31, 47, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Du lịch (Chuyên ngành Hướng dẫn du lịch) đào tạ..." with entities "[[3, 43, 'Major'], [58, 112, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thiết kế đồ họa đào tạo ngành Liên kết quốc tế ..." with entities "[[3, 18, 'Major'], [33, 61, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Toán ứng dụng đào tạo ngành Tiên tiến: Luật (Ch..." with entities "[[3, 16, 'Major'], [31, 74, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật xây dựng đào tạo ngành Tiêu chuẩn có y..." with entities "[[3, 20, 'Major'], [35, 45, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Toán ứng dụng đào tạo ngành Liên kết quốc tế-K7..." with entities "[[3, 16, 'Major'], [31, 57, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật phần mềm đào tạo ngành Liên kết quốc t..." with entities "[[3, 20, 'Major'], [35, 61, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kiến trúc đào tạo ngành Tiên tiến: Luật (Chuyên..." with entities "[[3, 12, 'Major'], [27, 70, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Dược đào tạo ngành Liên kết quốc tế - K7340120L..." with entities "[[3, 7, 'Major'], [22, 50, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật xây dựng công trình giao thông đào tạo..." with entities "[[3, 42, 'Major'], [57, 83, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ngành Kỹ thuật xây dựng công trình giao thông thuộ..." with entities "[[6, 45, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điều khiển và tự động hóa đào tạo ngàn..." with entities "[[3, 37, 'Major'], [52, 80, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Ngôn ngữ Anh đào tạo ngành Tiêu chuẩn có yêu cầ..." with entities "[[3, 15, 'Major'], [30, 40, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Du lịch (Chuyên ngành Quản lý du lịch) đào tạo ..." with entities "[[3, 41, 'Major'], [56, 82, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật cơ điện tử đào tạo ngành Tiêu chuẩn có..." with entities "[[3, 22, 'Major'], [37, 47, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thiết kế nội thất đào tạo ngành Liên kết quốc t..." with entities "[[3, 20, 'Major'], [35, 61, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Du lịch (Chuyên ngành Quản lý du lịch) đào tạo ..." with entities "[[3, 41, 'Major'], [56, 78, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Dược đào tạo ngành Liên kết quốc tế có yêu cầu ..." with entities "[[3, 7, 'Major'], [22, 38, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thống kê đào tạo ngành Liên kết quốc tế-K734020..." with entities "[[3, 11, 'Major'], [26, 52, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điện tử - viễn thông (Chuyên ngành Kỹ ..." with entities "[[3, 81, 'Major'], [96, 124, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Mạng máy tính và Truyền thông dữ liệu đào tạo n..." with entities "[[3, 40, 'Major'], [55, 109, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điều khiển và tự động hóa đào tạo ngàn..." with entities "[[3, 37, 'Major'], [52, 68, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kiểm toán (Chuyên ngành Kiểm toán và Phân tích ..." with entities "[[3, 58, 'Major'], [73, 99, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Khoa học máy tính đào tạo ngành Liên kết quốc t..." with entities "[[3, 20, 'Major'], [35, 61, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thiết kế thời trang đào tạo ngành Liên kết quốc..." with entities "[[3, 22, 'Major'], [37, 63, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật cơ điện tử đào tạo ngành Liên kết quốc..." with entities "[[3, 22, 'Major'], [37, 65, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Mạng máy tính và Truyền thông dữ liệu đào tạo n..." with entities "[[3, 40, 'Major'], [55, 64, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Du lịch (Chuyên ngành Hướng dẫn du lịch) đào tạ..." with entities "[[3, 43, 'Major'], [58, 80, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật xây dựng đào tạo ngành Tiên tiến có yê..." with entities "[[3, 20, 'Major'], [35, 44, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Ngôn ngữ Anh đào tạo ngành Tiên tiến: Luật (Chu..." with entities "[[3, 15, 'Major'], [30, 73, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Ngôn ngữ Trung Quốc đào tạo ngành Liên kết quốc..." with entities "[[3, 22, 'Major'], [37, 65, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Marketing đào tạo ngành Liên kết quốc tế - K748..." with entities "[[3, 12, 'Major'], [27, 55, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Mạng máy tính và Truyền thông dữ liệu đào tạo n..." with entities "[[3, 40, 'Major'], [55, 65, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật xây dựng công trình giao thông đào tạo..." with entities "[[3, 42, 'Major'], [57, 85, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thống kê đào tạo ngành Liên kết quốc tế - K7480..." with entities "[[3, 11, 'Major'], [26, 54, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Luật đào tạo ngành Tiên tiến: Luật (Chuyên ngàn..." with entities "[[3, 7, 'Major'], [22, 76, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điều khiển và tự động hóa đào tạo ngàn..." with entities "[[3, 37, 'Major'], [52, 95, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật cơ điện tử đào tạo ngành Tiên tiến có ..." with entities "[[3, 22, 'Major'], [37, 46, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật hóa học đào tạo ngành Tiên tiến: Luật ..." with entities "[[3, 19, 'Major'], [34, 77, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Ngôn ngữ Trung Quốc đào tạo ngành Liên kết quốc..." with entities "[[3, 22, 'Major'], [37, 63, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Marketing đào tạo ngành Liên kết quốc tế có yêu..." with entities "[[3, 12, 'Major'], [27, 43, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật xây dựng công trình giao thông đào tạo..." with entities "[[3, 42, 'Major'], [57, 79, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thiết kế đồ họa đào tạo ngành Tiêu chuẩn có yêu..." with entities "[[3, 18, 'Major'], [33, 43, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Du lịch (Chuyên ngành Quản lý du lịch) đào tạo ..." with entities "[[3, 41, 'Major'], [56, 110, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Luật đào tạo ngành Liên kết quốc tế có yêu cầu ..." with entities "[[3, 7, 'Major'], [22, 38, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thiết kế đồ họa đào tạo ngành Liên kết quốc tế-..." with entities "[[3, 18, 'Major'], [33, 59, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điều khiển và tự động hóa đào tạo ngàn..." with entities "[[3, 37, 'Major'], [52, 74, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Ngôn ngữ Trung Quốc đào tạo ngành Tiên tiến: Lu..." with entities "[[3, 22, 'Major'], [37, 80, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thống kê đào tạo ngành Liên kết quốc tế - K7340..." with entities "[[3, 11, 'Major'], [26, 54, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật xây dựng công trình giao thông đào tạo..." with entities "[[3, 42, 'Major'], [57, 111, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Khoa học môi trường đào tạo ngành Tiên tiến: Lu..." with entities "[[3, 22, 'Major'], [37, 91, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Ngôn ngữ Anh đào tạo ngành Liên kết quốc tế - K..." with entities "[[3, 15, 'Major'], [30, 58, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật xây dựng đào tạo ngành Đại học bằng ti..." with entities "[[3, 20, 'Major'], [35, 57, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Luật đào tạo ngành Tiên tiến: Luật (Chuyên ngàn..." with entities "[[3, 7, 'Major'], [22, 65, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thiết kế nội thất đào tạo ngành Đại học bằng ti..." with entities "[[3, 20, 'Major'], [35, 57, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điện tử - viễn thông đào tạo ngành Liê..." with entities "[[3, 32, 'Major'], [47, 75, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thiết kế nội thất đào tạo ngành Tiêu chuẩn có y..." with entities "[[3, 20, 'Major'], [35, 45, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thiết kế đồ họa đào tạo ngành Tiên tiến: Luật (..." with entities "[[3, 18, 'Major'], [33, 76, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Khoa học môi trường đào tạo ngành Liên kết quốc..." with entities "[[3, 22, 'Major'], [37, 53, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kiểm toán (Chuyên ngành Kiểm toán và Phân tích ..." with entities "[[3, 58, 'Major'], [73, 101, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật xây dựng đào tạo ngành Liên kết quốc t..." with entities "[[3, 20, 'Major'], [35, 63, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Dược đào tạo ngành Liên kết quốc tế-K7340201M c..." with entities "[[3, 7, 'Major'], [22, 48, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điện đào tạo ngành Liên kết quốc tế - ..." with entities "[[3, 16, 'Major'], [31, 59, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điện đào tạo ngành Liên kết quốc tế có..." with entities "[[3, 16, 'Major'], [31, 47, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Marketing đào tạo ngành Tiên tiến có yêu cầu gì..." with entities "[[3, 12, 'Major'], [27, 36, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật hóa học đào tạo ngành Liên kết quốc tế..." with entities "[[3, 19, 'Major'], [34, 60, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Thiết kế thời trang đào tạo ngành Tiên tiến: Lu..." with entities "[[3, 22, 'Major'], [37, 91, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật điện tử - viễn thông (Chuyên ngành Kỹ ..." with entities "[[3, 81, 'Major'], [96, 150, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ...
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ NN Anh đào tạo ngành Tiên tiến có yêu cầu gì?" with entities "[[3, 9, 'Major'], [24, 33, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ kỹ điện đào tạo ngành Liên kết quốc tế - K74801..." with entities "[[3, 10, 'Major'], [25, 53, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Học ngành Hán ngữ hệ Tiên tiến mất bao lâu?" with entities "[[10, 17, 'Major'], [21, 30, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ kỹ điện đào tạo ngành Tiên tiến: Luật (Chuyên n..." with entities "[[3, 10, 'Major'], [25, 79, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Hán ngữ đào tạo ngành Tiêu chuẩn có yêu cầu gì?" with entities "[[3, 10, 'Major'], [25, 35, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học ngành Hán ngữ hệ Đại học bằng tiếng A..." with entities "[[19, 26, 'Major'], [30, 52, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ kế toan đào tạo ngành Liên kết quốc tế - K73401..." with entities "[[3, 10, 'Major'], [25, 53, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ kỹ điện đào tạo ngành Tiên tiến: Luật (Chuyên n..." with entities "[[3, 10, 'Major'], [25, 68, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Hán ngữ đào tạo ngành Liên kết quốc tế có yêu c..." with entities "[[3, 10, 'Major'], [25, 41, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ kế toan đào tạo ngành Tiêu chuẩn có yêu cầu gì?" with entities "[[3, 10, 'Major'], [25, 35, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học ngành NN Trung hệ Liên kết quốc tế-K7..." with entities "[[19, 27, 'Major'], [31, 57, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học ngành tiếng Trung hệ Liên kết quốc tế..." with entities "[[19, 30, 'Major'], [34, 60, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học ngành Hán ngữ hệ Liên kết quốc tế-K73..." with entities "[[19, 26, 'Major'], [30, 56, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ khoa học mt đào tạo ngành Tiên tiến: Luật (Chuy..." with entities "[[3, 14, 'Major'], [29, 72, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ khoa học mt đào tạo ngành Tiên tiến có yêu cầu ..." with entities "[[3, 14, 'Major'], [29, 38, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Điểm chuẩn ngành Hán ngữ hệ Liên kết quốc tế - K73..." with entities "[[17, 24, 'Major'], [28, 56, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học ngành Hán ngữ hệ Tiên tiến" with entities "[[19, 26, 'Major'], [30, 39, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Học ngành NN Trung hệ Liên kết quốc tế - K7340120L..." with entities "[[10, 18, 'Major'], [22, 50, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Học ngành tiếng Trung hệ Liên kết quốc tế - K73401..." with entities "[[10, 21, 'Major'], [25, 53, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Học ngành Hán ngữ hệ Liên kết quốc tế - K7340120L ..." with entities "[[10, 17, 'Major'], [21, 49, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật xd đào tạo ngành Tiên tiến: Luật (Chuy..." with entities "[[3, 14, 'Major'], [29, 83, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật xd đào tạo ngành Tiên tiến: Luật (Chuy..." with entities "[[3, 14, 'Major'], [29, 72, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ kế toan đào tạo ngành Tiên tiến: Luật (Chuyên n..." with entities "[[3, 10, 'Major'], [25, 79, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Kỹ thuật xd đào tạo ngành Liên kết quốc tế có y..." with entities "[[3, 14, 'Major'], [29, 45, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Ngành Hán ngữ hệ Tiên tiến có học bổng không?" with entities "[[6, 13, 'Major'], [17, 26, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Học ngành Hán ngữ hệ Tiên tiến: Luật (Chuyên ngành..." with entities "[[10, 17, 'Major'], [21, 75, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Điểm chuẩn ngành Hán ngữ hệ Tiên tiến: Luật (Chuyê..." with entities "[[17, 24, 'Major'], [28, 71, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học ngành NN Trung hệ Tiêu chuẩn" with entities "[[19, 27, 'Major'], [31, 41, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học ngành tiếng Trung hệ Tiêu chuẩn" with entities "[[19, 30, 'Major'], [34, 44, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Tôi muốn học ngành Hán ngữ hệ Tiêu chuẩn" with entities "[[19, 26, 'Major'], [30, 40, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Điểm chuẩn ngành Hán ngữ hệ Tiên tiến năm nay là b..." with entities "[[17, 24, 'Major'], [28, 37, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Điểm chuẩn ngành Hán ngữ hệ Đại học bằng tiếng Anh..." with entities "[[17, 24, 'Major'], [28, 50, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ Hán ngữ đào tạo ngành Đại học bằng tiếng Anh có..." with entities "[[3, 10, 'Major'], [25, 47, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ kỹ điện đào tạo ngành Tiên tiến có yêu cầu gì?" with entities "[[3, 10, 'Major'], [25, 34, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Hệ kỹ điện đào tạo ngành Liên kết quốc tế-K7340201..." with entities "[[3, 10, 'Major'], [25, 51, 'Programme']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# D:\Programs\Python\Python311\Lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ngành Kỹ thuật điện tử -viễn thông" with entities "[[6, 19, 'Major']]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Số mẫu hợp lệ: 20623

# %% [markdown]
# ## III. Training

# %%
# Huấn luyện mô hình
optimizer = nlp.begin_training()
for i in range(10):
    random.shuffle(TRAIN_DATA_CLEAN)
    losses = {}
    print(f"Epoch {i+1}")
    batches = minibatch(TRAIN_DATA_CLEAN, size=32)  # batch size
    for batch in tqdm(batches, desc=f"Training Epoch {i+1}"):
        nlp.update(batch, drop=0.3, sgd=optimizer, losses=losses)
    print(f"Loss: {losses}")
# Out:
# Epoch 1
# Training Epoch 1: 645it [00:36, 17.62it/s]
# Loss: {'ner': 9080.839780246164}
# Epoch 2
# Training Epoch 2: 645it [00:48, 13.18it/s]
# Loss: {'ner': 55.36435844555748}
# Epoch 3
# Training Epoch 3: 645it [01:41,  6.35it/s]
# Loss: {'ner': 70.94317114290878}
# Epoch 4
# Training Epoch 4: 645it [01:57,  5.50it/s]
# Loss: {'ner': 47.855244215799004}
# Epoch 5
# Training Epoch 5: 645it [02:00,  5.35it/s]
# Loss: {'ner': 43.481046284180145}
# Epoch 6
# Training Epoch 6: 645it [02:00,  5.33it/s]
# Loss: {'ner': 43.32321751304146}
# Epoch 7
# Training Epoch 7: 645it [02:01,  5.32it/s]
# Loss: {'ner': 33.16445981936081}
# Epoch 8
# Training Epoch 8: 645it [02:37,  4.10it/s]
# Loss: {'ner': 23.344967616084833}
# Epoch 9
# Training Epoch 9: 645it [03:17,  3.26it/s]
# Loss: {'ner': 35.63873693676629}
# Epoch 10
# Training Epoch 10: 645it [03:15,  3.30it/s]
# Loss: {'ner': 28.20683312001551}

# %% [markdown]
# ## IV. Save model

# %%
# nlp.to_disk("../ner_model")
# print("Mô hình đã lưu vào thư mục ner_model")

# Lưu mô hình
nlp.to_disk("../ner_model_cleaned")
print("Đã lưu mô hình vào thư mục ner_model_cleaned")
# Out:
# Đã lưu mô hình vào thư mục ner_model_cleaned

# %% [markdown]
# ## V. Save invalid NER data

# %%
# with open("data/invalid_ner_data.json", "w", encoding="utf-8") as f:
#     json.dump(invalid_data, f, ensure_ascii=False, indent=2)
# print(f"Đã lưu {len(invalid_data)} câu lỗi vào file: data/invalid_ner_data.json")

# %% [markdown]
# ## VI. Test

# %%
ner_nlp = spacy.load("../ner_model_cleaned")

# %%
# ======== METHODS =========
def extract_entities(text: str):
    doc = ner_nlp(text)
    return [
        {
            "text": ent.text,
            "start": ent.start_char,
            "end": ent.end_char,
            "label": ent.label_
        }
        for ent in doc.ents
    ]

# %%
text = "ngành khmt thuộc hệ đào tạo nào" 
entities = extract_entities(text)

print(entities)
# Out:
# [{'text': 'khmt', 'start': 6, 'end': 10, 'label': 'Major'}]
